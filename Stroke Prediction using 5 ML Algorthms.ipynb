# %%
# %pip install pandas
# %pip install seaborn
# %pip install matplotlib
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize']= (5,5)

# %%
data=pd.read_csv(r'C:\Users\prana\Desktop\Stroke Probability Detector\healthcare-dataset-stroke-data.csv')

# %%
data
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 0     62452    Male  82.00             1              0          Yes
# 1     40163  Female  82.00             1              0          Yes
# 2     67895  Female  82.00             1              1          Yes
# 3     39373  Female  82.00             1              0          Yes
# 4     27596  Female  82.00             1              0          Yes
# ...     ...     ...    ...           ...            ...          ...
# 5105  22877    Male   0.16             0              0           No
# 5106   8247    Male   0.16             0              0           No
# 5107  41500    Male   0.16             0              0           No
# 5108  47350  Female   0.08             0              0           No
# 5109  29955    Male   0.08             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
data.shape
# Out:
# (5110, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# # Lets fill Null values

# %%
data['bmi'].value_counts()
# Out:
# bmi
# 28.7    41
# 28.4    38
# 27.7    37
# 26.1    37
# 27.6    37
#         ..
# 52.5     1
# 57.3     1
# 53.5     1
# 49.4     1
# 13.0     1
# Name: count, Length: 418, dtype: int64

# %%
data['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %%
data['bmi'].fillna(data['bmi'].mean(),inplace=True)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_5824\620513141.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bmi'].fillna(data['bmi'].mean(),inplace=True)

# %%
data['bmi'].describe()
# Out:
# count    5110.000000
# mean       28.893237
# std         7.698018
# min        10.300000
# 25%        23.800000
# 50%        28.400000
# 75%        32.800000
# max        97.600000
# Name: bmi, dtype: float64

# %%
data.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data.drop('id',axis=1,inplace=True)

# %%
data
# Out:
#       gender    age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  82.00             1              0          Yes        Private
# 1     Female  82.00             1              0          Yes        Private
# 2     Female  82.00             1              1          Yes       Govt_job
# 3     Female  82.00             1              0          Yes  Self-employed
# 4     Female  82.00             1              0          Yes        Private
# ...      ...    ...           ...            ...          ...            ...
# 5105    Male   0.16             0              0           No       children
# 5106    Male   0.16             0              0           No       children
# 5107    Male   0.16             0              0           No       children
# 5108  Female   0.08             0              0           No       children
# 5109    Male   0.08             0              0           No       children
#
# ...

# %% [markdown]
# # outlier removation

# %%
data.plot(kind='box')
plt.show()

# %% [markdown]
# # Label Encoding

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  82.0             1              0          Yes        Private
# 1  Female  82.0             1              0          Yes        Private
# 2  Female  82.0             1              1          Yes       Govt_job
# 3  Female  82.0             1              0          Yes  Self-employed
# 4  Female  82.0             1              0          Yes        Private
#
#   Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0          Rural             227.28  33.300000     never smoked       1
# 1          Urban             222.52  28.893237  formerly smoked       1
# 2          Urban             215.94  27.900000  formerly smoked       1
# 3          Urban             196.92  22.200000     never smoked       1
# 4          Urban             115.71  31.100000  formerly smoked       1

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
gender=enc.fit_transform(data['gender'])

# %%
smoking_status=enc.fit_transform(data['smoking_status'])

# %%
work_type=enc.fit_transform(data['work_type'])
Residence_type=enc.fit_transform(data['Residence_type'])
ever_married=enc.fit_transform(data['ever_married'])
data['gender']=gender

# %%
data['ever_married']=ever_married
data['Residence_type']=Residence_type
data['smoking_status']=smoking_status
data['work_type']=work_type

# %%
data
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  82.00             1              0             1          2
# 1          0  82.00             1              0             1          2
# 2          0  82.00             1              1             1          0
# 3          0  82.00             1              0             1          3
# 4          0  82.00             1              0             1          2
# ...      ...    ...           ...            ...           ...        ...
# 5105       1   0.16             0              0             0          4
# 5106       1   0.16             0              0             0          4
# 5107       1   0.16             0              0             0          4
# 5108       0   0.08             0              0             0          4
# 5109       1   0.08             0              0             0          4
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# ...

# %%
data
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  82.00             1              0             1          2
# 1          0  82.00             1              0             1          2
# 2          0  82.00             1              1             1          0
# 3          0  82.00             1              0             1          3
# 4          0  82.00             1              0             1          2
# ...      ...    ...           ...            ...           ...        ...
# 5105       1   0.16             0              0             0          4
# 5106       1   0.16             0              0             0          4
# 5107       1   0.16             0              0             0          4
# 5108       0   0.08             0              0             0          4
# 5109       1   0.08             0              0             0          4
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   int32
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   int32
#  5   work_type          5110 non-null   int32
#  6   Residence_type     5110 non-null   int32
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                5110 non-null   float64
#  9   smoking_status     5110 non-null   int32
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int32(5), int64(3)
# memory usage: 339.5 KB

# %% [markdown]
# # Spliting the data for train and test

# %% [markdown]
# X ---train_X,test_X 80/20
# Y ---train_Y,test_Y

# %%
X=data.drop('stroke',axis=1)

# %%
X.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  82.0             1              0             1          2
# 1       0  82.0             1              0             1          2
# 2       0  82.0             1              1             1          0
# 3       0  82.0             1              0             1          3
# 4       0  82.0             1              0             1          2
#
#    Residence_type  avg_glucose_level        bmi  smoking_status
# 0               0             227.28  33.300000               2
# 1               1             222.52  28.893237               1
# 2               1             215.94  27.900000               1
# 3               1             196.92  22.200000               2
# 4               1             115.71  31.100000               1

# %%
Y=data['stroke']

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=101)

# %%
X_train
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 3831       0  25.00             0              0             0          0
# 5085       1   0.56             0              0             0          4
# 1593       1  57.00             0              0             1          3
# 1324       0  60.00             0              0             1          2
# 123        0  80.00             1              0             1          2
# ...      ...    ...           ...            ...           ...        ...
# 4171       0  19.00             0              0             0          3
# 599        1  73.00             0              1             1          0
# 1361       1  60.00             0              0             1          3
# 1547       1  57.00             0              0             1          2
# 4959       1   2.00             0              0             0          4
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
X_test
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 5031       0   1.4             0              0             0          4
# 4017       0  22.0             0              0             1          2
# 744        0  70.0             0              0             1          2
# 1799       0  54.0             0              0             1          2
# 2314       0  48.0             0              0             1          2
# ...      ...   ...           ...            ...           ...        ...
# 4795       0   5.0             0              0             0          4
# 4641       1   9.0             0              0             0          4
# 1320       0  60.0             0              0             1          2
# 1098       1  63.0             0              0             1          3
# 4634       1  10.0             0              0             0          4
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
Y_train
# Out:
# 3831    0
# 5085    0
# 1593    0
# 1324    0
# 123     1
#        ..
# 4171    0
# 599     1
# 1361    0
# 1547    0
# 4959    0
# Name: stroke, Length: 4088, dtype: int64

# %%
Y_test
# Out:
# 5031    0
# 4017    0
# 744     1
# 1799    0
# 2314    0
#        ..
# 4795    0
# 4641    0
# 1320    0
# 1098    0
# 4634    0
# Name: stroke, Length: 1022, dtype: int64

# %% [markdown]
# # normalize

# %%
data.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  5110.000000  5110.000000   5110.000000    5110.000000   5110.000000
# mean      0.414286    43.226614      0.097456       0.054012      0.656164
# std       0.493044    22.612647      0.296607       0.226063      0.475034
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       2.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  5110.000000     5110.000000        5110.000000  5110.000000
# mean      2.167710        0.508023         106.147677    28.893237
# std       1.090293        0.499985          45.283560     7.698018
# ...

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %% [markdown]
# # Lets save the Scaler object

# %%
import pickle
import os

# %%
scaler_path=os.path.join('H:\Stroke prediction project\Models\scaler.pkl')
with open(scaler_path, 'wb') as scaler_file:
    pickle.dump(std,scaler_file)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\prana\AppData\Local\Temp\ipykernel_5824\975143331.py:1: SyntaxWarning: invalid escape sequence '\S'
#   scaler_path=os.path.join('H:\Stroke prediction project\Models\scaler.pkl')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[81], line 2
#       1 scaler_path=os.path.join('H:\Stroke prediction project\Models\scaler.pkl')
# ----> 2 with open(scaler_path, 'wb') as scaler_file:
#       3     pickle.dump(std,scaler_file)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
# ...

# %%
X_train_std
# Out:
# array([[-0.83822764,  0.52508975, -0.32887595, ..., -0.86380214,
#          0.32750249,  0.58675012],
#        [-0.83822764,  1.27625065, -0.32887595, ..., -0.49693827,
#          0.5478543 , -0.34367443],
#        [ 1.19059095, -0.53537271, -0.32887595, ..., -0.77181304,
#         -0.39836227,  0.58675012],
#        ...,
#        [-0.83822764,  0.70183349, -0.32887595, ..., -0.36430791,
#         -0.10023924, -1.27409897],
#        [ 1.19059095,  0.70183349, -0.32887595, ...,  1.93039389,
#          0.19788379, -1.27409897],
#        [-0.83822764,  0.30416007, -0.32887595, ..., -0.96147227,
#         -0.70944717,  0.58675012]])

# %%
X_test_std
# Out:
# array([[-0.83822764, -1.021418  , -0.32887595, ...,  0.23941148,
#         -1.52604504,  0.58675012],
#        [-0.83822764,  0.03904446, -0.32887595, ...,  0.08252747,
#          0.21084566,  1.51717466],
#        [-0.83822764,  1.23206472,  3.04066013, ...,  1.92252784,
#          0.35342624,  0.58675012],
#        ...,
#        [-0.83822764,  0.65764755, -0.32887595, ...,  0.81996973,
#         -0.37243853,  1.51717466],
#        [-0.83822764,  1.49718033, -0.32887595, ..., -0.68987501,
#         -0.89091336, -1.27409897],
#        [ 1.19059095,  1.49718033, -0.32887595, ..., -0.26117525,
#          0.61266365, -1.27409897]])

# %% [markdown]
# # training

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train_std,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.feature_importances_
# Out:
# array([0.04163357, 0.17634908, 0.01636484, 0.01904455, 0.01025572,
#        0.03725076, 0.04566058, 0.33684931, 0.2483743 , 0.06821729])

# %%
X_train.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')

# %%
Y_pred=dt.predict(X_test_std)

# %%
Y_test
# Out:
# 5031    0
# 4017    0
# 744     0
# 1799    0
# 2314    0
#        ..
# 4795    0
# 4641    0
# 1320    0
# 1098    0
# 4634    0
# Name: stroke, Length: 1022, dtype: int64

# %%
X_test
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 5031       0  20.0             0              0             0          2
# 4017       0  44.0             0              0             1          2
# 744        0  71.0             1              0             1          2
# 1799       1  34.0             0              0             1          2
# 2314       1  82.0             0              0             1          2
# ...      ...   ...           ...            ...           ...        ...
# 4795       1  62.0             0              0             1          3
# 4641       0  45.0             0              0             1          0
# 1320       0  58.0             0              1             1          2
# 1098       0  77.0             0              0             1          2
# 4634       1  77.0             0              0             1          2
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt=accuracy_score(Y_test,Y_pred)

# %%
ac_dt
# Out:
# 0.8992172211350293

# %%
import joblib
model_path=os.path.join('H:\Stroke prediction project\Models\dt.sav')
joblib.dump(dt,model_path)
# Out:
# ['H:\\Stroke prediction project\\Models\\dt.sav']

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=lr.predict(X_test_std)

# %%
ac_lr=accuracy_score(Y_test,Y_pred)

# %%
ac_lr
# Out:
# 0.9471624266144814

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X_train_std, Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred=knn.predict(X_test_std)

# %%
ac_knn=accuracy_score(Y_test, Y_pred)

# %%
ac_knn
# Out:
# 0.9452054794520548

# %%
ac_lr
# Out:
# 0.9471624266144814

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X_train_std, Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred=rf.predict(X_test)
# Out:
# C:\Users\Aditya Prabhakar\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
ac_rf=accuracy_score(Y_test, Y_pred)

# %%
ac_rf
# Out:
# 0.9471624266144814

# %%
ac_knn
# Out:
# 0.9452054794520548

# %%
ac_lr
# Out:
# 0.9471624266144814

# %%
ac_dt
# Out:
# 0.8992172211350293

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
sv=SVC()

# %%
sv.fit(X_train_std, Y_train)
# Out:
# SVC()

# %%
Y_pred=sv.predict(X_test_std)

# %%
ac_sv=accuracy_score(Y_test, Y_pred)

# %%
ac_sv
# Out:
# 0.9471624266144814

# %%
ac_lr
# Out:
# 0.9471624266144814

# %%
plt.bar(['Decision Tree', 'Logistic', 'KNN', 'Random Forest', 'SVM'],[ac_dt, ac_lr, ac_knn, ac_rf, ac_sv])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.show()

# %%
import pickle
filename = r'H:\Stroke prediction project\finalized_model_lr.sav'
pickle.dump(lr, open(filename,'wb'))
